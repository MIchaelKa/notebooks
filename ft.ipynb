# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# Normal distributed x and y vector with mean 0 and standard deviation 1
# x = np.random.normal(0, 1, 500)
# x = np.random.normal(0, 3.1458*2, 500)
x = np.arange(0,10,0.1)
y = np.sin(x)

# %%
# X

# %%
X = np.vstack((x, y)).T
# X = np.hstack((x, y))

# plt.scatter(X[:, 0], X[:, 1])
plt.plot(X[:, 0], X[:, 1])
plt.title('Generated Data')
plt.axis('equal');

# %%
# синус и косинус это же просто разораванная и отмасштабированная оружность

# %%
from scipy.fft import fft, fftfreq

# %%
SAMPLE_RATE = 44100  # Гц
DURATION = 5  # Секунды

# %%
# число точек в normalized_tone
N = SAMPLE_RATE * DURATION

# yf = fft(normalized_tone)
yf = fft(y)
xf = fftfreq(N, 1 / SAMPLE_RATE)

plt.plot(xf, np.abs(yf))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-020f40ae4474> in <module>
#       6 xf = fftfreq(N, 1 / SAMPLE_RATE)
#       7
# ----> 8 plt.plot(xf, np.abs(yf))
#       9 plt.show()
#
# ~/Developer/ml/projects/p3env/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/Developer/ml/projects/p3env/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/Developer/ml/projects/p3env/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/Developer/ml/projects/p3env/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (220500,) and (10,)
